# %% [markdown]
# ***Using a Proxy to Access a Website***

# %% [markdown]
# ***Extracting a pool of links***

# %%
from lxml.html import fromstring
import requests
from itertools import cycle
import traceback
def get_proxies():
  url = 'https://free-proxy-list.net/'
  response = requests.get(url)
  parser = fromstring(response.text)
  proxies = set()

  for i in parser.xpath('//tbody/tr')[:200]:
    if i.xpath('.//td[7][contains(text(),"yes")]'):
      proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
      proxies.add(proxy)
  return proxies
proxies = get_proxies()
proxy_pool = cycle(proxies)
url = 'https://www.cnet.com/news/best-vpn/'
for i in range(1,100):
#Get a proxy from the pool
  proxy = next(proxy_pool)
  print("Request #%d"%i)
  try:
    response = requests.get(url,proxies={"http": proxy, "https": proxy})
    print(response)
    
  except:
 
    print("Skipping, Connnection error")
# Out:
# Request #1
# <Response [200]>
# Request #2
# <Response [200]>
# Request #3
# Skipping, Connnection error
# Request #4
# <Response [200]>
# Request #5
# Skipping, Connnection error
# Request #6
# Skipping, Connnection error
# Request #7
# Skipping, Connnection error
# Request #8
# Skipping, Connnection error
# Request #9
# <Response [200]>
# Request #10
# <Response [200]>
# Request #11
# <Response [200]>
# Request #12
# Skipping, Connnection error
# Request #13
# <Response [200]>
# Request #14
# <Response [200]>
# Request #15
# Skipping, Connnection error
# Request #16
# Skipping, Connnection error
# Request #17
# <Response [200]>
# Request #18
# <Response [200]>
# Request #19
# Skipping, Connnection error
# Request #20
# Skipping, Connnection error
# Request #21
# Skipping, Connnection error
# Request #22
# Skipping, Connnection error
# Request #23
# Skipping, Connnection error
# Request #24
# Skipping, Connnection error
# Request #25
# <Response [200]>
# Request #26
# ...

# %% [markdown]
# # OBSERVATIONS AND PERCENTAGE EFFICIENCY:
# Total number of iterations = 81
# Total number of connection errors = 53
# Total number of success iterations = 28
# Success Percentage = 34.57
# Percentage Error = 65.43%
#
# # SITES USED:
# Free Proxies: https://free-proxy-list.net/    \n
#  Target Site: https://www.cnet.com/news/best-vpn/
#
# # OBSERVATIONS:
# 1) Iterations were extremely time consuming.
# 2) Most of the proxies used were inefficient and unreliable.
# 3) As per the information gathered, such open/ shared proxies as they are often infected by malware and viruses.
# 4) Links were valid for a very short time span.
#
# ```
# # This is formatted as code
# ```
