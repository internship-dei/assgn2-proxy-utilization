# %%
from lxml.html import fromstring
import requests
from itertools import cycle
import traceback
def get_proxies():
    url = 'https://free-proxy-list.net/'
    response = requests.get(url)
    parser = fromstring(response.text)
    proxies = set()

    for i in parser.xpath('//tbody/tr')[:200]:
      if  i.xpath('.//td[7][contains(text(),"yes")]'):
          proxy = ":".join([i.xpath('.//td[1]/text()')[0], i.xpath('.//td[2]/text()')[0]])
          proxies.add(proxy)
    return proxies
proxies = get_proxies()
proxy_pool = cycle(proxies)
url = "https://www.hongkiat.com/blog/free-music-online/amp/"
for i in range(1,100):
    proxy = next(proxy_pool)
    print("Request #%d"%i)
    try:
      response = requests.get(url,proxies={"https":proxy, "https":proxy})
      print(response)
    except:
      print("skipping,connection error")
# Out:
# Request #1
# skipping,connection error
# Request #2
# skipping,connection error
# Request #3
# skipping,connection error
# Request #4
# skipping,connection error
# Request #5
# skipping,connection error
# Request #6
# <Response [200]>
# Request #7
# <Response [200]>
# Request #8
# skipping,connection error
# Request #9
# skipping,connection error
# Request #10
# <Response [200]>
# Request #11
# skipping,connection error
# Request #12
# <Response [200]>
# Request #13
# <Response [200]>
# Request #14
# <Response [200]>
# Request #15
# skipping,connection error
# Request #16
# skipping,connection error
# Request #17
# <Response [200]>
# Request #18
# skipping,connection error
# Request #19
# <Response [200]>
# Request #20
# <Response [200]>
# Request #21
# <Response [200]>
# Request #22
# skipping,connection error
# Request #23
# <Response [200]>
# Request #24
# <Response [200]>
# Request #25
# skipping,connection error
# Request #26
# skipping,connection error
# Request #27
# ...

# %% [markdown]
# **Used Website**
#
# https://www.hongkiat.com/blog/free-music-online/amp/

# %% [markdown]
# **Stats and Observations**
#
# Total number of iterations = 99
# Total number of success iterations = 55
# Total number of connection errors = 44
# Success Percentage = 55.55%
# Percentage Error = 44.45%
